# %% [markdown]
# ### 第一天的学习
# *python 环境配置

# %%
for i in range(3):
    print("hello,world")
# Out:
# hello,world
# hello,world
# hello,world

# %%
print('i am zhz')
# Out:
# i am zhz

# %%
print('i like read 荣格自传')
# Out:
# i like read 荣格自传
